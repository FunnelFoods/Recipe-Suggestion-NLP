# %%
import difflib
import re
import numpy as np
import pandas as pd
import ast
from fuzzywuzzy import fuzz 

import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Reads the food with 6,000 rows
with open("../Reference and Datasets/foodList.txt") as f:
    foodList = f.read().splitlines()
    
# Reads the large food data with 200,000 rows
food_nutrient_large = pd.read_csv('../NutrientData/Food Data/food_nutrients_dict.csv')

# Reads categorized food with 16,000 rows
food_categ = pd.read_csv('../NutrientData/food_categorized_nurtrients_w_name.csv')

# %%
# Reads expiration date
expr = pd.read_csv('../Reference and Datasets/expiration_data.csv')
expr_dates = dict(zip(expr['name'], expr['expireIn']))

# Cleans up the one nan float value in expr_names
expr_names = list(expr_dates.keys())
epxr_names = [e for e in expr_names if type(e) != float] 

# Maps from category index to expr date
expr_categ = {
    1: 2,
    2: 7,
    3: 10,
    4: 365,
    5: 7,
    6: 3,
    7: 3,
    8: 240,
    9: 3,
    10: 2,
    11: 7,
    12: 180,
    13: 3,
    14: 30,
    15: 3,
    16: 365,
    17: 3,
    18: 5,
    19: 180,
    20: 30, # pasta
    21: 7, #FAST FOOD
    22: 3,
    23: 365,
    25: 2,
    26: 7
}

# %%
# Cleans up foodList
temp = list(filter(lambda x: x not in ['baby', 'producer', 'red', '85% lean', 'baked', 'leg','greater than 3% juice', 'family style'
                                      ,'polish', 'greek', 'on the border', 'tlc', 'low calorie', 'milk producer', 'producer milk', 'green', 'grade'], foodList))
foodList = temp

# %%
# Creates a series of food_names with comma, for regex extracting purposes
food_comma = food_categ['food_name'] + ','

# Extracts the food's generic names 
food_categ['generic'] = food_comma.str.extract(r'^([^,]*),')[0]

# %%
# Get rid of commas, colons, and other special characters 
food_clean_name = food_categ['food_name'].str.replace(r'[^a-zA-Z0-9 ]', "").str.replace(r' +', ' ')

# %%
# Compiles a list of foodnames with 200k data and with 16k data respectively
foodlist_large = food_nutrient_large['name'].tolist()
foodlist_categ = food_clean_name.tolist()
foodlist_generic = food_categ['generic'].tolist()

# %%
# RegEx generator to match with decimals surrounded by indices
regexp = re.compile(r'^[^a-z]+\d\.\d')
findFoodName = re.compile("([^\.]+) \d+\.")

# %%
# sample receipts. Input 4 works the best.
inp_one = [ '1805 University AVe. 2.53', 'Berkeley CA 94703 2.53', 'Store # 186 (510) 204-9074 2.53', 'UPEN 8:0OAM 10 9:0OPM DAILY 2.53', '21 SEASONI NG SALUE 2,202 2.53', '0 SUNFL OWER 2.53', 'SEA SALI FINE CRYSTALS 26.502 2.53', 'SOURDOUGT BATARD 2.53', 'GRAPES GREEN SEEDI ESS 2LB 2.53', 'BIRTHDAY CARO 2.53', 'BBQ CUT SALMON 2.53', 'SLCD SAL AMI PPRED COLUMUS 2.53', 'ORCANTC CHICKL TENDERS 2.53', 'PECORTNO ROMAW 2.53', 'SPICE INO BIACK PEPPER 207 2.53', '8.0 2.53', '5.75 2.53', '1.99 2.53', '3.49 2.53', '5.49 2.53', '1.38 2.53', 'EGGS EXIRA LARGE CAGE FRE BRU 2.53', 'BACON ABr UNCURED DAY RUBBED 2.53', 'POTATO RUSSET EACH 2.53', '@ 0.69/A 2.53', '2EA 2.53', 'AVDCADO EACH HASS 2.53', '@1.59/EA 2.53', '0.98 2.53', 'A- LAR 1C EACIH A9/t) UNCA 2.53', '0.49/EA 2.53', 'IRSH KFRRYOOD UNSA I 2.53', '2LA 2.53', 'BUTTLR 2.53', 'BuftA EACII 2.53' ]
inp_two = [ 'LIUR TED 2.53','Regular Price 2.53','Card Savings 2.53','6.49 S 2.53','8.49 2.53','2.00- 2.53','SEAFOOD 2.53','SALMON ATLANTIC 2.53','SMOKED SALMON LOX 2.53','13.98 S 2.53','9.99 S 2.53','PRODUCE 2.53','1 2.53','QTY 2.53','CUCUMBERS 2.53','1.00 S 2.53','0.39 1b @ $1.99 /lb 2.53','WT 2.53','0.78 S 2.53','RED ROMA TOMATOES 2.53','3.99 S 2.53','SWT YOUNG COCONUT 2.53','BOK CHOY BABY 2.53','GINGER ROOT 2.53','0.51 lb @ $2.99 /1b 2.53','1.52 S 2.53','WT 2.53','0.10 lb @ $3.99 /lb 2.53','0.40 S 2.53','3.98 S 2.53','WT 2.53','2 QTY PORTABELLA 2.53','0.21 lb @ $2.99 /lb 2.53','WT 2.53','0.63 S 2.53','6.99 S 2.53','SHALLOTS 2.53','0 ORGNC GAPES RED 2.53','1.68 Ib @ $0.99 /1b 2.53','WT 2.53','1.66 S 2.53','ORG BANANAS 2.53','DELI 2.53','6.80 2.53','PORT SALUT WHEEL 2.53' ]
inp_three = [ 'GROCERY 2.53','99 S 2.53','HIME SHALLOTS NOR1 2.53','549 2.53','O50- 2.53','Regular Price 2.53','Card Savings 2.53','DYNASTY RICE 5 LB 2.53','KASHI CRL GOLEA 2.53','Regular Price 2.53','Card Savings 2.53','2 QTY DE CECCO 8 2.53','KIKKOMAN GRGNC SO 2.53','Regular Price 2.53','Card Savings 2.53','PANDA EXPRESS MNDR 2.53','Resular Price 2.53','Card Savinss 2.53','MARINONNECRN R 2.53','LUNDBERG RTCE HT 2.53','LUNDBERG RICE 2.53','GROCERY COUPON 2.53','Resular Price 2.53','Card Savinas 2.53','0TY MP PRENIUN 2.53','1195 2.53','395 S 2.53','4.99 2.53','1.00- 2.53','2.95 S 2.53','3.99 2.53','1.00- 2.53','350S 2.53','0.01 2.53','0.0t- 2.53','NP TONAT0 ASIL 2.53','200S 2.53','GROCERY 2.53' ]
inp_four = [ 'PRODUCE 2.53','MSHRM PORTABE! LO 2.53','S FARMS SPACH 2.53','Regular Price 2.53','Card Savings 2.53','2 QTY CANTALQUPE 2.53','Regular 2.53','Card Savings 2.53','3.99 c 2.53','1.99 2.53','0.32- 2.53','Price 2.53','5.98 2.53','0.98- 2.53','O. 66 lb @ $i.49 /lb 2.53','JUt 30 YLW ONIONS 2.53','GREEN SDLSS GRAPES 2.53','CABBAGE SAVOY 2.53','GINGER ROOT 2.53','0.98 2.53','7.71 2.53','5.63 2.53','WT 2.53','WT 2.53','WT 2.53','2.58 lb @ $2 99 /lb 2.53','2.83 lb @ $1..99 /lb 2.53','0.41 lb @ $3.99 /1b 2.53','1.00 lb @ $2.99 /1b 2.53','1.64 2.53','WT 2.53','TOMATOES ON VINE 2.53','RASPBERRIES RED 2.53','WT 2.53','2.99 2.53','6.9: 2.53','5.99 2.53','0 ORGNC SWEET CORN 2.53','1 QTY 2.53','0 ORGNC MSHRH LIHTE 2.53','0 ORGNC FRESH HERB 2.53','3.50 2.53','5.00 2.53','ADDITIONAL DISCOUNTS 2.53','5.0 2.53','BASKET $5 OFf 0un Brands 2.53' ]

# %%
def findExpr(name, categ):
    bestRatio = 0
    best = ""
    for e in epxr_names:
        r = fuzz.ratio(name, e)
        if r > bestRatio:
            bestRatio = r
            best = e
    if bestRatio <= 60:
        return name, expr_categ.get(categ,7)
    return best, expr_dates[best]

# TEST: findExpr('ginger root', 11)
# Out:
# ('ginger root', 7)

# %%
# Finds the best match of the food item on the receipt from the database. Outputs a list of dictionaries.
all_scores = []
def matchReceipt(inp):  
    food = []
    for line in inp:
        if regexp.search(line):
            if findFoodName.search(line):
                words = findFoodName.search(line).group(0)
                bestRatio = 0
                pos = 0
                name = ""
                for i, f in enumerate(foodlist_categ):
                    r = fuzz.token_set_ratio(words, f)
                    if r > bestRatio:
                        pos = i
                        name = f
                        bestRatio = r
                if bestRatio > 50:
                    d = food_categ.loc[pos, 'nutrients']
                    gen = food_categ.loc[pos, 'generic']
                    food.append([words, name, gen, ast.literal_eval(d)])  
    return food

# %%
def advanceMatchReceipt(inp):
    final = []
    clean_orig_pair = {}
    for line in inp:
        if regexp.search(line):
            if findFoodName.search(line):
                orig = findFoodName.search(line).group(0)
                bestRatio = 0
                name = ""
                for i, f in enumerate(foodList):
                    r = fuzz.token_set_ratio(orig, f)
                    if r > bestRatio:
                        name = f
                        bestRatio = r
                if bestRatio > 65:
                    clean_orig_pair[name] = [orig, bestRatio]
    for clean in clean_orig_pair.keys():
        bestRatio = 0
        pos = 0
        name = ""
        for i, f in enumerate(foodlist_categ):
            r = fuzz.ratio(clean, f)*0.5 + fuzz.token_set_ratio(clean_orig_pair[clean][0].lower(), f)*0.5
            if r > bestRatio:
                pos = i
                name = f
                bestRatio = r
        if bestRatio > 60:
            gen = food_categ.loc[pos, 'generic']
            categ = int(food_categ.loc[pos, 'food_category_id'])
            e = findExpr(gen, categ)
            d = food_categ.loc[pos, 'nutrients']
            nutri = ast.literal_eval(d)
            final.append([clean_orig_pair[clean][0], clean, nutri, e[1]])
#             final.append([clean_orig_pair[clean][0], clean, name, e])
    return final

# %%
advanceMatchReceipt(inp_two)
# Out:
# [['SMOKED SALMON LOX 2.',
#   'salmon',
#   {'Energy': 117.0,
#    'Folate, DFE': 2.0,
#    'Retinol': 26.0,
#    'Vitamin A, RAE': 26.0,
#    'Protein': 18.28,
#    'Ash': 2.62,
#    'Iron, Fe': 0.85,
#    'Magnesium, Mg': 18.0,
#    'Phosphorus, P': 164.0,
#    'Sodium, Na': 2000.0,
#    'Copper, Cu': 0.23,
#    'Manganese, Mn': 0.02,
#    'Vitamin A, IU': 88.0,
#    'Thiamin': 0.02,
#    'Riboflavin': 0.1,
#    'Folate, total': 2.0,
#    'Vitamin B-12': 3.26,
#    'Folate, food': 2.0,
#    'Tryptophan': 0.2,
#    'Threonine': 0.8,
#    'Methionine': 0.54,
#    'Phenylalanine': 0.71,
#    'Tyrosine': 0.62,
#    'Alanine': 1.11,
#    'Glutamic acid': 2.73,
#    'Glycine': 0.88,
#    'Proline': 0.65,
#    'Cholesterol': 23.0,
#    'Fatty acids, total saturated': 0.93,
#    '14:0': 0.18,
#    '22:6 n-3 (DHA)': 0.27,
#    '16:1': 0.3,
#    '20:5 n-3 (EPA)': 0.18,
#    '22:5 n-3 (DPA)': 0.07,
#    'Total lipid (fat)': 4.32,
#    'Water': 72.0,
#    'Calcium, Ca': 11.0,
#    'Potassium, K': 175.0,
#    'Zinc, Zn': 0.31,
#    'Niacin': 4.72,
#    'Pantothenic acid': 0.87,
#    'Isoleucine': 0.84,
#    'Leucine': 1.49,
#    'Lysine': 1.68,
#    'Cystine': 0.2,
#    'Valine': 0.94,
#    'Arginine': 1.09,
#    'Histidine': 0.54,
#    'Aspartic acid': 1.87,
#    'Serine': 0.75,
#    '16:0': 0.56,
#    '18:0': 0.19,
#    '18:1': 0.95,
#    '18:2': 0.47,
#    '20:1': 0.47,
#    '22:1': 0.3,
#    'Fatty acids, total monounsaturated': 2.02,
#    'Fatty acids, total polyunsaturated': 1.0,
#    'Vitamin B-6': 0.28,
#    'Selenium, Se': 38.1},
#   1],
#  ['RED ROMA TOMATOES 2.', 'tomatoes red', {'Water': 92.8}, 7],
#  ['SWT YOUNG COCONUT 2.',
#   'coconut-nut',
#   {'Vitamin K (phylloquinone)': 0.6,
#    '17:0': 0.01,
#    '24:0': 0.03,
#    '18:1 c': 6.25,
#    '18:2 n-6 c,c': 1.68,
#    'Fatty acids, total trans-monoenoic': 0.02,
#    '18:3 n-3 c,c,c (ALA)': 0.02,
#    '22:0': 0.02,
#    'Fatty acids, total trans': 0.03,
#    'Fatty acids, total saturated': 82.5,
#    '8:0': 6.8,
#    '12:0': 41.8,
#    '14:0': 16.7,
#    'Ash': 0.03,
#    'Iron, Fe': 0.05,
#    'Energy': 833.0,
#    'Tocopherol, delta': 0.18,
#    'Tocotrienol, gamma': 0.36,
#    'Tocotrienol, delta': 0.25,
#    'Total lipid (fat)': 99.1,
#    'Vitamin E (alpha-tocopherol)': 0.11,
#    'Water': 0.03,
#    'Calcium, Ca': 1.0,
#    'Zinc, Zn': 0.02,
#    'Tocopherol, beta': 0.6,
#    'Tocotrienol, alpha': 2.17,
#    'Tocotrienol, beta': 0.13,
#    '4:0': 0.01,
#    '6:0': 0.48,
#    '10:0': 5.39,
#    '16:0': 8.64,
#    '18:0': 2.52,
#    '20:0': 0.08,
#    'Fatty acids, total monounsaturated': 6.31,
#    'Fatty acids, total polyunsaturated': 1.7,
#    '15:0': 0.02,
#    '18:1 t': 0.02,
#    '18:2 t not further defined': 0.01,
#    '16:1 c': 0.02,
#    '20:1': 0.04,
#    'Carbohydrate, by difference': 0.84,
#    'Fatty acids, total trans-dienoic': 0.01,
#    '20:1 c': 0.04,
#    '18:2 c': 1.68,
#    '18:3 c': 0.02,
#    'Total fat (NLEA)': 90.5},
#   365],
#  ['GINGER ROOT 2.',
#   'ginger',
#   {'Water': 78.89,
#    'Sugars, total including NLEA': 1.7,
#    'Calcium, Ca': 16.0,
#    'Potassium, K': 415.0,
#    'Zinc, Zn': 0.34,
#    'Total lipid (fat)': 0.75,
#    'Vitamin E (alpha-tocopherol)': 0.26,
#    'Niacin': 0.75,
#    'Pantothenic acid': 0.2,
#    'Vitamin B-6': 0.16,
#    '20:1': 0.01,
#    '16:0': 0.12,
#    '18:0': 0.02,
#    '18:1': 0.12,
#    '18:2': 0.12,
#    '18:3': 0.03,
#    '16:1': 0.02,
#    'Vitamin C, total ascorbic acid': 5.0,
#    'Thiamin': 0.02,
#    'Riboflavin': 0.03,
#    'Folate, total': 11.0,
#    'Vitamin K (phylloquinone)': 0.1,
#    '8:0': 0.01,
#    '12:0': 0.04,
#    '14:0': 0.02,
#    'Phytosterols': 15.0,
#    'Ash': 0.77,
#    'Iron, Fe': 0.6,
#    'Magnesium, Mg': 43.0,
#    'Phosphorus, P': 34.0,
#    'Sodium, Na': 13.0,
#    'Copper, Cu': 0.23,
#    'Manganese, Mn': 0.23,
#    'Energy': 80.0,
#    'Protein': 1.82,
#    'Folate, food': 11.0,
#    'Carbohydrate, by difference': 17.77,
#    'Choline, total': 28.8,
#    'Folate, DFE': 11.0,
#    'Isoleucine': 0.05,
#    'Leucine': 0.07,
#    'Lysine': 0.06,
#    'Cystine': 0.01,
#    'Valine': 0.07,
#    'Arginine': 0.04,
#    'Histidine': 0.03,
#    'Aspartic acid': 0.21,
#    'Serine': 0.04,
#    'Fatty acids, total monounsaturated': 0.15,
#    'Fatty acids, total polyunsaturated': 0.15,
#    'Fiber, total dietary': 2.0,
#    'Fatty acids, total saturated': 0.2,
#    'Tryptophan': 0.01,
#    'Threonine': 0.04,
#    'Methionine': 0.01,
#    'Phenylalanine': 0.04,
#    'Tyrosine': 0.02,
#    'Alanine': 0.03,
#    'Glutamic acid': 0.16,
#    'Glycine': 0.04,
#    'Proline': 0.04,
#    'Selenium, Se': 0.7},
#   7],
#  ['2 QTY PORTABELLA 2.',
#   'portabella',
#   {'Campesterol': 2.0,
#    '16:1': 0.01,
#    '18:1 c': 0.01,
#    '18:2 n-6 c,c': 0.15,
#    '17:0': 0.0,
#    'Fatty acids, total saturated': 0.01,
#    '22:0': 0.0,
#    '16:1 c': 0.0,
#    'Fatty acids, total monounsaturated': 0.04,
#    'Fatty acids, total polyunsaturated': 0.3,
#    '15:0': 0.0,
#    '20:0': 0.0,
#    '18:1': 0.02,
#    '18:2': 0.15,
#    'Isoleucine': 0.08,
#    'Leucine': 0.13,
#    'Lysine': 0.12,
#    'Cystine': 0.01,
#    'Valine': 0.08,
#    'Arginine': 0.08,
#    'Histidine': 0.06,
#    'Aspartic acid': 0.22,
#    'Serine': 0.09,
#    'Folate, total': 28.0,
#    'Tryptophan': 0.04,
#    'Threonine': 0.1,
#    'Methionine': 0.03,
#    'Phenylalanine': 0.08,
#    'Tyrosine': 0.01,
#    'Alanine': 0.17,
#    'Glutamic acid': 0.32,
#    'Glycine': 0.1,
#    'Proline': 0.08,
#    'Protein': 2.11,
#    'Ash': 0.85,
#    'Fructose': 0.49,
#    '14:1': 0.0,
#    'Fiber, total dietary': 1.3,
#    'Iron, Fe': 0.31,
#    'Phosphorus, P': 108.0,
#    'Sodium, Na': 9.0,
#    'Copper, Cu': 0.29,
#    'Manganese, Mn': 0.07,
#    'Thiamin': 0.06,
#    'Riboflavin': 0.13,
#    'Vitamin B-12': 0.05,
#    'Dihydrophylloquinone': 1.8,
#    'Betaine': 6.1,
#    'Niacin': 4.49,
#    'Pantothenic acid': 1.14,
#    'Vitamin B-6': 0.15,
#    'Choline, total': 21.2,
#    'Tocotrienol, alpha': 0.02,
#    'Vitamin D2 (ergocalciferol)': 0.3,
#    'Calcium, Ca': 3.0,
#    'Potassium, K': 364.0,
#    'Zinc, Zn': 0.53,
#    'Selenium, Se': 18.6,
#    'Vitamin E (alpha-tocopherol)': 0.02,
#    'Glucose (dextrose)': 2.01,
#    'Water': 92.82,
#    'Total lipid (fat)': 0.35,
#    'Folate, food': 28.0,
#    'Vitamin D (D2 + D3)': 0.3,
#    'Energy': 22.0,
#    'Carbohydrate, by difference': 3.87,
#    'Sugars, total including NLEA': 2.5,
#    'Vitamin D': 10.0,
#    'Folate, DFE': 28.0},
#   1],
#  ['SHALLOTS 2.',
#   'shallot',
#   {'Carbohydrate, by difference': 16.8,
#    'Energy': 301.0,
#    'Folate, DFE': 34.0,
#    'Total lipid (fat)': 0.1,
#    'Fatty acids, total monounsaturated': 0.01,
#    'Fatty acids, total polyunsaturated': 0.04,
#    'Isoleucine': 0.11,
#    'Leucine': 0.15,
#    'Lysine': 0.12,
#    'Valine': 0.11,
#    'Arginine': 0.18,
#    'Histidine': 0.04,
#    'Aspartic acid': 0.23,
#    'Serine': 0.11,
#    '16:0': 0.02,
#    '18:0': 0.0,
#    '18:1': 0.01,
#    '18:2': 0.04,
#    '18:3': 0.0,
#    'Water': 79.8,
#    'Calcium, Ca': 37.0,
#    'Potassium, K': 334.0,
#    'Zinc, Zn': 0.4,
#    'Niacin': 0.2,
#    'Pantothenic acid': 0.29,
#    'Vitamin B-6': 0.34,
#    'Iron, Fe': 1.2,
#    'Magnesium, Mg': 21.0,
#    'Phosphorus, P': 60.0,
#    'Sodium, Na': 12.0,
#    'Copper, Cu': 0.09,
#    'Manganese, Mn': 0.29,
#    'Tryptophan': 0.03,
#    'Threonine': 0.1,
#    'Methionine': 0.03,
#    'Phenylalanine': 0.08,
#    'Tyrosine': 0.07,
#    'Alanine': 0.11,
#    'Glutamic acid': 0.52,
#    'Glycine': 0.12,
#    'Proline': 0.16,
#    'Protein': 2.5,
#    'Ash': 0.8,
#    'Fatty acids, total saturated': 0.02,
#    'Vitamin C, total ascorbic acid': 8.0,
#    'Thiamin': 0.06,
#    'Riboflavin': 0.02,
#    'Folate, total': 34.0,
#    'Phytosterols': 5.0,
#    'Sugars, total including NLEA': 7.87,
#    'Choline, total': 11.3,
#    'Lutein + zeaxanthin': 8.0,
#    'Vitamin E (alpha-tocopherol)': 0.04,
#    'Vitamin A, IU': 4.0,
#    'Carotene, beta': 3.0,
#    'Fiber, total dietary': 3.2,
#    'Vitamin K (phylloquinone)': 0.8,
#    'Folate, food': 34.0,
#    'Selenium, Se': 1.2},
#   1],
#  ['ORG BANANAS 2.',
#   'bananas dehydrated',
#   {'Fatty acids, total saturated': 0.11,
#    '12:0': 0.0,
#    '14:0': 0.0,
#    '16:1': 0.01,
#    'Energy': 89.0,
#    'Vitamin A, IU': 64.0,
#    'Vitamin A, RAE': 3.0,
#    'Folate, food': 20.0,
#    'Fluoride, F': 2.2,
#    'Choline, total': 9.8,
#    '10:0': 0.0,
#    '16:0': 0.1,
#    '18:0': 0.0,
#    '18:1': 0.02,
#    '18:2': 0.05,
#    '18:3': 0.03,
#    'Fatty acids, total monounsaturated': 0.03,
#    'Fatty acids, total polyunsaturated': 0.07,
#    'Carbohydrate, by difference': 22.84,
#    'Folate, DFE': 20.0,
#    'Betaine': 0.1,
#    'Phytosterols': 16.0,
#    'Vitamin K (phylloquinone)': 0.5,
#    'Tocopherol, delta': 0.01,
#    'Vitamin C, total ascorbic acid': 8.7,
#    'Thiamin': 0.03,
#    'Riboflavin': 0.07,
#    'Folate, total': 20.0,
#    'Tryptophan': 0.01,
#    'Threonine': 0.03,
#    'Methionine': 0.01,
#    'Phenylalanine': 0.05,
#    'Tyrosine': 0.01,
#    'Alanine': 0.04,
#    'Glutamic acid': 0.15,
#    'Glycine': 0.04,
#    'Proline': 0.03,
#    'Carotene, beta': 26.0,
#    'Carotene, alpha': 25.0,
#    'Fiber, total dietary': 2.6,
#    'Iron, Fe': 0.26,
#    'Magnesium, Mg': 27.0,
#    'Phosphorus, P': 22.0,
#    'Sodium, Na': 1.0,
#    'Copper, Cu': 0.08,
#    'Manganese, Mn': 0.27,
#    'Protein': 1.09,
#    'Ash': 0.82,
#    'Starch': 5.38,
#    'Fructose': 4.85,
#    'Sugars, total including NLEA': 12.23,
#    'Calcium, Ca': 5.0,
#    'Potassium, K': 358.0,
#    'Zinc, Zn': 0.15,
#    'Sucrose': 2.39,
#    'Glucose (dextrose)': 4.98,
#    'Maltose': 0.01,
#    'Water': 74.91,
#    'Total lipid (fat)': 0.33,
#    'Isoleucine': 0.03,
#    'Leucine': 0.07,
#    'Lysine': 0.05,
#    'Cystine': 0.01,
#    'Valine': 0.05,
#    'Arginine': 0.05,
#    'Histidine': 0.08,
#    'Aspartic acid': 0.12,
#    'Serine': 0.04,
#    'Lutein + zeaxanthin': 22.0,
#    'Tocopherol, gamma': 0.02,
#    'Tocotrienol, alpha': 0.06,
#    'Niacin': 0.66,
#    'Pantothenic acid': 0.33,
#    'Vitamin B-6': 0.37,
#    'Selenium, Se': 1.0,
#    'Vitamin E (alpha-tocopherol)': 0.1},
#   5]]

# %%
[e for e in epxr_names if e == 'tomato']
food_categ[food_categ['generic'] == 'ginger root']
list(food_categ['food_category_id'].unique())
# Out:
# [11.0,
#  7.0,
#  1.0,
#  4.0,
#  16.0,
#  12.0,
#  9.0,
#  18.0,
#  2.0,
#  6.0,
#  5.0,
#  15.0,
#  19.0,
#  25.0,
#  13.0,
#  10.0,
#  14.0,
#  23.0,
#  17.0,
#  20.0,
#  21.0,
#  22.0,
#  3.0,
#  24.0,
#  8.0]

# %%
matchReceipt(inp_two)
# Out:
# [['LIUR TED 2.',
#   'butter salted',
#   'butter',
#   {'4:0': 3.23,
#    '6:0': 2.01,
#    '10:0': 2.53,
#    '16:0': 21.7,
#    '18:0': 10.0,
#    '20:0': 0.14,
#    '20:1': 0.1,
#    '18:1 t': 2.98,
#    '18:2 CLAs': 0.27,
#    '16:1 c': 0.96,
#    '18:3 n-3 c,c,c (ALA)': 0.32,
#    '17:0': 0.56,
#    '18:2 i': 0.3,
#    '18:1 c': 16.98,
#    '18:2 n-6 c,c': 2.17,
#    '8:0': 1.19,
#    '12:0': 2.59,
#    '14:0': 7.44,
#    'Iron, Fe': 0.02,
#    'Magnesium, Mg': 2.0,
#    'Phosphorus, P': 24.0,
#    'Cholesterol': 215.0,
#    'Vitamin B-12': 0.17,
#    'Potassium, K': 24.0,
#    'Zinc, Zn': 0.09,
#    'Fluoride, F': 2.8,
#    'Sodium, Na': 643.0,
#    'Folate, total': 3.0,
#    'Energy': 2999.0,
#    'Folate, DFE': 3.0,
#    'Vitamin E (alpha-tocopherol)': 2.32,
#    '18:1': 19.96,
#    '18:2': 2.73,
#    '18:3': 0.32,
#    'Fatty acids, total monounsaturated': 21.02,
#    'Fatty acids, total polyunsaturated': 3.04,
#    'Fatty acids, total trans-polyenoic': 0.3,
#    'Fatty acids, total trans': 3.28,
#    'Fatty acids, total saturated': 51.37,
#    'Vitamin K (phylloquinone)': 7.0,
#    'Folate, food': 3.0,
#    'Vitamin A, IU': 2499.0,
#    'Retinol': 671.0,
#    'Vitamin A, RAE': 684.0,
#    'Fatty acids, total trans-monoenoic': 2.98,
#    '16:1': 0.96,
#    'Isoleucine': 0.05,
#    'Leucine': 0.08,
#    'Lysine': 0.07,
#    'Cystine': 0.01,
#    'Valine': 0.06,
#    'Arginine': 0.03,
#    'Histidine': 0.02,
#    'Aspartic acid': 0.06,
#    'Serine': 0.05,
#    'Niacin': 0.04,
#    'Pantothenic acid': 0.11,
#    'Vitamin B-6': 0.0,
#    'Total lipid (fat)': 81.11,
#    'Carbohydrate, by difference': 0.06,
#    'Thiamin': 0.0,
#    'Riboflavin': 0.03,
#    'Tryptophan': 0.01,
#    'Threonine': 0.04,
#    'Methionine': 0.02,
#    'Phenylalanine': 0.04,
#    'Tyrosine': 0.04,
#    'Alanine': 0.03,
#    'Glutamic acid': 0.18,
#    'Glycine': 0.02,
#    'Proline': 0.08,
#    'Protein': 0.85,
#    'Ash': 2.11,
#    'Carotene, beta': 158.0,
#    'Beta-sitosterol': 4.0,
#    'Sugars, total including NLEA': 0.06,
#    'Calcium, Ca': 24.0,
#    'Water': 16.17,
#    'Selenium, Se': 1.0,
#    'Choline, total': 18.8,
#    'Betaine': 0.3}],
#  ['SALMON ATLANTIC 2.',
#   'fish salmon atlantic wild cooked dry heat',
#   'fish',
#   {'Energy': 182.0,
#    'Folate, DFE': 29.0,
#    'Retinol': 13.0,
#    'Vitamin A, RAE': 13.0,
#    'Protein': 25.44,
#    'Ash': 3.26,
#    'Thiamin': 0.28,
#    'Riboflavin': 0.49,
#    'Folate, total': 29.0,
#    'Vitamin B-12': 3.05,
#    'Folate, food': 29.0,
#    'Tryptophan': 0.28,
#    'Threonine': 1.12,
#    'Iron, Fe': 1.03,
#    'Magnesium, Mg': 37.0,
#    'Phosphorus, P': 256.0,
#    'Sodium, Na': 56.0,
#    'Copper, Cu': 0.32,
#    'Manganese, Mn': 0.02,
#    'Vitamin A, IU': 44.0,
#    'Methionine': 0.75,
#    'Phenylalanine': 0.99,
#    'Tyrosine': 0.86,
#    'Alanine': 1.54,
#    'Glutamic acid': 3.8,
#    'Glycine': 1.22,
#    'Proline': 0.9,
#    'Cholesterol': 71.0,
#    'Fatty acids, total saturated': 1.26,
#    '14:0': 0.18,
#    '22:6 n-3 (DHA)': 1.43,
#    '16:1': 0.32,
#    '20:5 n-3 (EPA)': 0.41,
#    '22:5 n-3 (DPA)': 0.37,
#    'Total lipid (fat)': 8.13,
#    'Water': 59.62,
#    'Calcium, Ca': 15.0,
#    'Potassium, K': 628.0,
#    'Zinc, Zn': 0.82,
#    'Isoleucine': 1.17,
#    'Leucine': 2.07,
#    'Lysine': 2.34,
#    'Niacin': 10.08,
#    'Pantothenic acid': 1.92,
#    'Vitamin B-6': 0.94,
#    'Cystine': 0.27,
#    'Valine': 1.31,
#    'Arginine': 1.52,
#    'Histidine': 0.75,
#    'Aspartic acid': 2.6,
#    'Serine': 1.04,
#    '16:0': 0.81,
#    '18:0': 0.27,
#    '18:1': 1.73,
#    '18:2': 0.22,
#    '18:3': 0.38,
#    '20:4': 0.34,
#    '18:4': 0.11,
#    '20:1': 0.29,
#    '22:1': 0.36,
#    'Fatty acids, total monounsaturated': 2.7,
#    'Fatty acids, total polyunsaturated': 3.26,
#    'Selenium, Se': 46.8}],
#  ['SMOKED SALMON LOX 2.',
#   'fish salmon chinook smoked lox regular',
#   'fish',
#   {'Energy': 117.0,
#    'Folate, DFE': 2.0,
#    'Retinol': 26.0,
#    'Vitamin A, RAE': 26.0,
#    'Protein': 18.28,
#    'Ash': 2.62,
#    'Iron, Fe': 0.85,
#    'Magnesium, Mg': 18.0,
#    'Phosphorus, P': 164.0,
#    'Sodium, Na': 2000.0,
#    'Copper, Cu': 0.23,
#    'Manganese, Mn': 0.02,
#    'Vitamin A, IU': 88.0,
#    'Thiamin': 0.02,
#    'Riboflavin': 0.1,
#    'Folate, total': 2.0,
#    'Vitamin B-12': 3.26,
#    'Folate, food': 2.0,
#    'Tryptophan': 0.2,
#    'Threonine': 0.8,
#    'Methionine': 0.54,
#    'Phenylalanine': 0.71,
#    'Tyrosine': 0.62,
#    'Alanine': 1.11,
#    'Glutamic acid': 2.73,
#    'Glycine': 0.88,
#    'Proline': 0.65,
#    'Cholesterol': 23.0,
#    'Fatty acids, total saturated': 0.93,
#    '14:0': 0.18,
#    '22:6 n-3 (DHA)': 0.27,
#    '16:1': 0.3,
#    '20:5 n-3 (EPA)': 0.18,
#    '22:5 n-3 (DPA)': 0.07,
#    'Total lipid (fat)': 4.32,
#    'Water': 72.0,
#    'Calcium, Ca': 11.0,
#    'Potassium, K': 175.0,
#    'Zinc, Zn': 0.31,
#    'Niacin': 4.72,
#    'Pantothenic acid': 0.87,
#    'Isoleucine': 0.84,
#    'Leucine': 1.49,
#    'Lysine': 1.68,
#    'Cystine': 0.2,
#    'Valine': 0.94,
#    'Arginine': 1.09,
#    'Histidine': 0.54,
#    'Aspartic acid': 1.87,
#    'Serine': 0.75,
#    '16:0': 0.56,
#    '18:0': 0.19,
#    '18:1': 0.95,
#    '18:2': 0.47,
#    '20:1': 0.47,
#    '22:1': 0.3,
#    'Fatty acids, total monounsaturated': 2.02,
#    'Fatty acids, total polyunsaturated': 1.0,
#    'Vitamin B-6': 0.28,
#    'Selenium, Se': 38.1}],
#  ['PRODUCE 2.',
#   'milk producer fluid',
#   'milk',
#   {'Energy': 64.0,
#    'Folate, DFE': 5.0,
#    'Retinol': 31.0,
#    'Vitamin A, RAE': 33.0,
#    'Total lipid (fat)': 3.66,
#    'Carbohydrate, by difference': 4.65,
#    'Water': 87.69,
#    'Calcium, Ca': 119.0,
#    'Potassium, K': 151.0,
#    'Zinc, Zn': 0.38,
#    'Isoleucine': 0.2,
#    'Leucine': 0.32,
#    'Lysine': 0.26,
#    'Cystine': 0.03,
#    'Valine': 0.22,
#    'Arginine': 0.12,
#    'Histidine': 0.09,
#    'Aspartic acid': 0.25,
#    'Serine': 0.18,
#    '4:0': 0.12,
#    '6:0': 0.07,
#    '10:0': 0.09,
#    '16:0': 0.96,
#    '18:0': 0.44,
#    '18:1': 0.92,
#    '18:2': 0.08,
#    '18:3': 0.05,
#    'Niacin': 0.08,
#    'Pantothenic acid': 0.31,
#    'Vitamin B-6': 0.04,
#    'Fatty acids, total monounsaturated': 1.06,
#    'Fatty acids, total polyunsaturated': 0.14,
#    'Protein': 3.28,
#    'Ash': 0.72,
#    '16:1': 0.08,
#    'Iron, Fe': 0.05,
#    'Magnesium, Mg': 13.0,
#    'Phosphorus, P': 93.0,
#    'Sodium, Na': 49.0,
#    'Copper, Cu': 0.01,
#    'Manganese, Mn': 0.0,
#    'Vitamin A, IU': 138.0,
#    'Vitamin C, total ascorbic acid': 1.5,
#    'Thiamin': 0.04,
#    'Riboflavin': 0.16,
#    'Folate, total': 5.0,
#    'Vitamin B-12': 0.36,
#    'Folate, food': 5.0,
#    'Tryptophan': 0.05,
#    'Threonine': 0.15,
#    'Methionine': 0.08,
#    'Phenylalanine': 0.16,
#    'Tyrosine': 0.16,
#    'Alanine': 0.11,
#    'Glutamic acid': 0.69,
#    'Glycine': 0.07,
#    'Proline': 0.32,
#    'Cholesterol': 14.0,
#    'Fatty acids, total saturated': 2.28,
#    '8:0': 0.04,
#    '12:0': 0.1,
#    '14:0': 0.37,
#    'Selenium, Se': 2.0}],
#  ['CUCUMBERS 2.',
#   'pickles cucumber sour',
#   'pickles',
#   {'Protein': 0.33,
#    'Ash': 3.13,
#    'Tryptophan': 0.0,
#    'Threonine': 0.01,
#    'Methionine': 0.0,
#    'Phenylalanine': 0.01,
#    'Tyrosine': 0.01,
#    'Alanine': 0.01,
#    'Glutamic acid': 0.1,
#    'Glycine': 0.01,
#    'Proline': 0.01,
#    'Vitamin C, total ascorbic acid': 1.0,
#    'Riboflavin': 0.01,
#    'Folate, total': 1.0,
#    'Phytosterols': 14.0,
#    'Fiber, total dietary': 1.2,
#    'Iron, Fe': 0.4,
#    'Magnesium, Mg': 4.0,
#    'Phosphorus, P': 14.0,
#    'Sodium, Na': 1208.0,
#    'Copper, Cu': 0.08,
#    'Manganese, Mn': 0.01,
#    'Total lipid (fat)': 0.2,
#    'Water': 94.08,
#    'Isoleucine': 0.01,
#    'Leucine': 0.01,
#    'Lysine': 0.01,
#    'Cystine': 0.0,
#    'Valine': 0.01,
#    'Arginine': 0.02,
#    'Histidine': 0.0,
#    'Aspartic acid': 0.02,
#    'Serine': 0.01,
#    'Potassium, K': 23.0,
#    'Zinc, Zn': 0.02,
#    'Pantothenic acid': 0.04,
#    'Vitamin B-6': 0.01,
#    'Carbohydrate, by difference': 2.26,
#    'Energy': 44.0,
#    'Sugars, total including NLEA': 1.06,
#    '16:0': 0.04,
#    '18:0': 0.0,
#    '18:1': 0.0,
#    '18:2': 0.03,
#    '18:3': 0.05,
#    'Fatty acids, total monounsaturated': 0.0,
#    'Fatty acids, total polyunsaturated': 0.08,
#    'Lutein + zeaxanthin': 43.0,
#    'Folate, DFE': 1.0,
#    'Vitamin E (alpha-tocopherol)': 0.09,
#    'Choline, total': 3.6,
#    'Vitamin A, IU': 191.0,
#    'Cryptoxanthin, beta': 47.0,
#    'Vitamin K (phylloquinone)': 47.0,
#    'Folate, food': 1.0,
#    'Fatty acids, total saturated': 0.05,
#    '12:0': 0.0,
#    '14:0': 0.0,
#    'Vitamin A, RAE': 10.0,
#    'Carotene, beta': 81.0,
#    'Carotene, alpha': 20.0}],
#  ['RED ROMA TOMATOES 2.',
#   'tomatoes canned red ripe diced',
#   'tomatoes',
#   {'Calcium, Ca': 30.0,
#    'Copper, Cu': 0.05,
#    'Iron, Fe': 0.57,
#    'Magnesium, Mg': 9.8,
#    'Manganese, Mn': 0.07,
#    'Phosphorus, P': 18.0,
#    'Potassium, K': 198.0,
#    'Sodium, Na': 125.0,
#    'Zinc, Zn': 0.12,
#    'Water': 94.6,
#    'Ash': 0.74,
#    'Total lipid (fat)': 0.5,
#    'Nitrogen': 0.14,
#    'Glucose (dextrose)': 1.5,
#    'Fructose': 1.49,
#    'Sugars, Total NLEA': 2.99,
#    'Protein': 0.84,
#    'Carbohydrate, by difference': 3.32,
#    'Energy': 76.0}],
#  ['SWT YOUNG COCONUT 2.',
#   'oil coconut',
#   'oil',
#   {'Vitamin K (phylloquinone)': 0.6,
#    '17:0': 0.01,
#    '24:0': 0.03,
#    '18:1 c': 6.25,
#    '18:2 n-6 c,c': 1.68,
#    'Fatty acids, total trans-monoenoic': 0.02,
#    '18:3 n-3 c,c,c (ALA)': 0.02,
#    '22:0': 0.02,
#    'Fatty acids, total trans': 0.03,
#    'Fatty acids, total saturated': 82.5,
#    '8:0': 6.8,
#    '12:0': 41.8,
#    '14:0': 16.7,
#    'Ash': 0.03,
#    'Iron, Fe': 0.05,
#    'Energy': 833.0,
#    'Tocopherol, delta': 0.18,
#    'Tocotrienol, gamma': 0.36,
#    'Tocotrienol, delta': 0.25,
#    'Total lipid (fat)': 99.1,
#    'Vitamin E (alpha-tocopherol)': 0.11,
#    'Water': 0.03,
#    'Calcium, Ca': 1.0,
#    'Zinc, Zn': 0.02,
#    'Tocopherol, beta': 0.6,
#    'Tocotrienol, alpha': 2.17,
#    'Tocotrienol, beta': 0.13,
#    '4:0': 0.01,
#    '6:0': 0.48,
#    '10:0': 5.39,
#    '16:0': 8.64,
#    '18:0': 2.52,
#    '20:0': 0.08,
#    'Fatty acids, total monounsaturated': 6.31,
#    'Fatty acids, total polyunsaturated': 1.7,
#    '15:0': 0.02,
#    '18:1 t': 0.02,
#    '18:2 t not further defined': 0.01,
#    '16:1 c': 0.02,
#    '20:1': 0.04,
#    'Carbohydrate, by difference': 0.84,
#    'Fatty acids, total trans-dienoic': 0.01,
#    '20:1 c': 0.04,
#    '18:2 c': 1.68,
#    '18:3 c': 0.02,
#    'Total fat (NLEA)': 90.5}],
#  ['BOK CHOY BABY 2.',
#   'babyfood cookies',
#   'babyfood',
#   {'Retinol': 6.0,
#    'Carotene, beta': 1.0,
#    'Vitamin E (alpha-tocopherol)': 0.46,
#    'Choline, total': 28.3,
#    'Cholesterol': 12.0,
#    'Sodium, Na': 300.0,
#    'Protein': 11.8,
#    'Ash': 2.0,
#    'Copper, Cu': 0.07,
#    'Manganese, Mn': 0.35,
#    'Vitamin A, IU': 23.0,
#    'Vitamin A, RAE': 6.0,
#    'Energy': 433.0,
#    'Fiber, total dietary': 0.2,
#    'Iron, Fe': 4.18,
#    'Magnesium, Mg': 49.0,
#    'Phosphorus, P': 179.0,
#    'Fatty acids, total trans': 0.02,
#    'Fatty acids, total saturated': 2.35,
#    '8:0': 0.02,
#    '12:0': 0.06,
#    '14:0': 0.27,
#    '22:0': 0.08,
#    '16:1': 0.12,
#    '17:0': 0.0,
#    'Vitamin C, total ascorbic acid': 7.0,
#    'Thiamin': 1.46,
#    'Riboflavin': 3.23,
#    'Folate, total': 93.0,
#    'Vitamin B-12': 0.46,
#    'Vitamin K (phylloquinone)': 1.1,
#    'Folate, food': 19.0,
#    'Folic acid': 74.0,
#    'Folate, DFE': 145.0,
#    'Lutein + zeaxanthin': 9.0,
#    'Niacin': 15.97,
#    'Pantothenic acid': 0.53,
#    'Vitamin B-6': 5.9,
#    '4:0': 0.08,
#    '6:0': 0.02,
#    '10:0': 0.06,
#    '16:0': 1.14,
#    '18:0': 0.6,
#    '20:0': 0.03,
#    '18:1': 5.85,
#    '18:2': 2.85,
#    '18:3': 0.03,
#    '20:1': 0.02,
#    'Sugars, total including NLEA': 24.2,
#    'Calcium, Ca': 101.0,
#    'Potassium, K': 501.0,
#    'Zinc, Zn': 1.1,
#    'Total lipid (fat)': 13.2,
#    'Carbohydrate, by difference': 67.1,
#    'Water': 5.9,
#    'Fatty acids, total monounsaturated': 5.99,
#    'Fatty acids, total polyunsaturated': 2.88,
#    'Selenium, Se': 17.2}],
#  ['GINGER ROOT 2.',
#   'ginger root raw',
#   'ginger root',
#   {'Water': 78.89,
#    'Sugars, total including NLEA': 1.7,
#    'Calcium, Ca': 16.0,
#    'Potassium, K': 415.0,
#    'Zinc, Zn': 0.34,
#    'Total lipid (fat)': 0.75,
#    'Vitamin E (alpha-tocopherol)': 0.26,
#    'Niacin': 0.75,
#    'Pantothenic acid': 0.2,
#    'Vitamin B-6': 0.16,
#    '20:1': 0.01,
#    '16:0': 0.12,
#    '18:0': 0.02,
#    '18:1': 0.12,
#    '18:2': 0.12,
#    '18:3': 0.03,
#    '16:1': 0.02,
#    'Vitamin C, total ascorbic acid': 5.0,
#    'Thiamin': 0.02,
#    'Riboflavin': 0.03,
#    'Folate, total': 11.0,
#    'Vitamin K (phylloquinone)': 0.1,
#    '8:0': 0.01,
#    '12:0': 0.04,
#    '14:0': 0.02,
#    'Phytosterols': 15.0,
#    'Ash': 0.77,
#    'Iron, Fe': 0.6,
#    'Magnesium, Mg': 43.0,
#    'Phosphorus, P': 34.0,
#    'Sodium, Na': 13.0,
#    'Copper, Cu': 0.23,
#    'Manganese, Mn': 0.23,
#    'Energy': 80.0,
#    'Protein': 1.82,
#    'Folate, food': 11.0,
#    'Carbohydrate, by difference': 17.77,
#    'Choline, total': 28.8,
#    'Folate, DFE': 11.0,
#    'Isoleucine': 0.05,
#    'Leucine': 0.07,
#    'Lysine': 0.06,
#    'Cystine': 0.01,
#    'Valine': 0.07,
#    'Arginine': 0.04,
#    'Histidine': 0.03,
#    'Aspartic acid': 0.21,
#    'Serine': 0.04,
#    'Fatty acids, total monounsaturated': 0.15,
#    'Fatty acids, total polyunsaturated': 0.15,
#    'Fiber, total dietary': 2.0,
#    'Fatty acids, total saturated': 0.2,
#    'Tryptophan': 0.01,
#    'Threonine': 0.04,
#    'Methionine': 0.01,
#    'Phenylalanine': 0.04,
#    'Tyrosine': 0.02,
#    'Alanine': 0.03,
#    'Glutamic acid': 0.16,
#    'Glycine': 0.04,
#    'Proline': 0.04,
#    'Selenium, Se': 0.7}],
#  ['2 QTY PORTABELLA 2.',
#   'mushrooms portabella grilled',
#   'mushrooms',
#   {'Starch': 0.43,
#    'Dihydrophylloquinone': 7.0,
#    'Folate, total': 19.0,
#    'Tocotrienol, alpha': 0.03,
#    'Menaquinone-4': 0.3,
#    '16:0': 0.04,
#    '18:0': 0.01,
#    '20:0': 0.0,
#    '18:1': 0.01,
#    '18:2': 0.23,
#    'Fatty acids, total monounsaturated': 0.01,
#    'Fatty acids, total polyunsaturated': 0.23,
#    'Fatty acids, total saturated': 0.06,
#    '22:0': 0.0,
#    '18:1 c': 0.01,
#    '18:2 n-6 c,c': 0.23,
#    'Choline, total': 32.8,
#    'Betaine': 11.5,
#    'Folate, DFE': 19.0,
#    'Vitamin D': 14.0,
#    'Vitamin D2 (ergocalciferol)': 0.3,
#    'Niacin': 6.26,
#    'Pantothenic acid': 1.26,
#    'Vitamin B-6': 0.12,
#    'Total lipid (fat)': 0.58,
#    'Carbohydrate, by difference': 4.44,
#    'Energy': 121.0,
#    'Glucose (dextrose)': 2.26,
#    'Water': 90.66,
#    'Sugars, total including NLEA': 2.26,
#    'Calcium, Ca': 3.0,
#    'Potassium, K': 437.0,
#    'Zinc, Zn': 0.65,
#    'Selenium, Se': 21.9,
#    'Isoleucine': 0.09,
#    'Leucine': 0.15,
#    'Lysine': 0.11,
#    'Cystine': 0.02,
#    'Valine': 0.41,
#    'Arginine': 0.12,
#    'Histidine': 0.06,
#    'Aspartic acid': 0.26,
#    'Serine': 0.12,
#    '10:0': 0.0,
#    '15:0': 0.0,
#    '16:1 c': 0.0,
#    '14:0': 0.0,
#    '14:1': 0.0,
#    '16:1': 0.0,
#    '17:0': 0.0,
#    '24:0': 0.0,
#    'Threonine': 0.12,
#    'Methionine': 0.04,
#    'Phenylalanine': 0.1,
#    'Tyrosine': 0.07,
#    'Alanine': 0.18,
#    'Glutamic acid': 0.47,
#    'Glycine': 0.11,
#    'Proline': 0.12,
#    'Fiber, total dietary': 2.2,
#    'Iron, Fe': 0.4,
#    'Magnesium, Mg': 13.0,
#    'Phosphorus, P': 135.0,
#    'Sodium, Na': 11.0,
#    'Copper, Cu': 0.39,
#    'Manganese, Mn': 0.07,
#    'Thiamin': 0.07,
#    'Riboflavin': 0.4,
#    'Protein': 3.28,
#    'Ash': 1.05,
#    'Vitamin D (D2 + D3)': 0.3,
#    'Folate, food': 19.0,
#    'Tryptophan': 0.04}],
#  ['SHALLOTS 2.',
#   'shallots freezedried',
#   'shallots',
#   {'Folate, DFE': 116.0,
#    'Fatty acids, total monounsaturated': 0.07,
#    'Fatty acids, total polyunsaturated': 0.2,
#    'Niacin': 1.0,
#    'Pantothenic acid': 1.41,
#    'Vitamin B-6': 1.68,
#    '16:0': 0.08,
#    '18:0': 0.01,
#    '18:1': 0.07,
#    '18:2': 0.18,
#    '18:3': 0.01,
#    'Isoleucine': 0.52,
#    'Leucine': 0.73,
#    'Lysine': 0.61,
#    'Valine': 0.54,
#    'Arginine': 0.89,
#    'Histidine': 0.21,
#    'Aspartic acid': 1.14,
#    'Serine': 0.56,
#    'Total lipid (fat)': 0.5,
#    'Carbohydrate, by difference': 80.7,
#    'Energy': 1457.0,
#    'Water': 2.0,
#    'Calcium, Ca': 183.0,
#    'Potassium, K': 1650.0,
#    'Zinc, Zn': 1.93,
#    'Protein': 12.3,
#    'Ash': 4.5,
#    'Iron, Fe': 6.0,
#    'Magnesium, Mg': 104.0,
#    'Phosphorus, P': 296.0,
#    'Sodium, Na': 59.0,
#    'Copper, Cu': 0.42,
#    'Manganese, Mn': 1.42,
#    'Fatty acids, total saturated': 0.08,
#    '14:0': 0.0,
#    'Vitamin C, total ascorbic acid': 39.0,
#    'Thiamin': 0.3,
#    'Riboflavin': 0.1,
#    'Folate, total': 116.0,
#    'Tryptophan': 0.14,
#    'Threonine': 0.48,
#    'Methionine': 0.13,
#    'Phenylalanine': 0.4,
#    'Tyrosine': 0.36,
#    'Alanine': 0.56,
#    'Glutamic acid': 2.54,
#    'Glycine': 0.61,
#    'Proline': 0.81,
#    'Vitamin A, IU': 21.0,
#    'Fiber, total dietary': 15.7,
#    'Vitamin K (phylloquinone)': 3.9,
#    'Vitamin A, RAE': 1.0,
#    'Carotene, beta': 13.0,
#    'Sugars, total including NLEA': 38.16,
#    'Choline, total': 55.0,
#    'Lutein + zeaxanthin': 38.0,
#    'Vitamin E (alpha-tocopherol)': 0.18,
#    'Folate, food': 116.0,
#    'Selenium, Se': 5.7}],
#  ['0 ORGNC GAPES RED 2.',
#   'applebees french fries',
#   "applebee's",
#   {'Total lipid (fat)': 13.17,
#    'Carbohydrate, by difference': 39.5,
#    'Energy': 1213.0,
#    'Water': 41.29,
#    'Calcium, Ca': 19.0,
#    'Potassium, K': 538.0,
#    'Vitamin E (alpha-tocopherol)': 0.93,
#    'Tocopherol, beta': 0.11,
#    'Tocopherol, gamma': 5.53,
#    'Tocotrienol, alpha': 0.07,
#    '10:0': 0.0,
#    '16:0': 1.51,
#    '18:0': 0.68,
#    '20:0': 0.04,
#    '18:1': 3.21,
#    '18:2': 5.02,
#    '18:3': 0.77,
#    '20:4': 0.01,
#    'Niacin': 2.18,
#    'Pantothenic acid': 0.5,
#    'Vitamin B-6': 0.2,
#    '20:1': 0.07,
#    '22:1': 0.0,
#    'Fatty acids, total monounsaturated': 3.31,
#    'Fatty acids, total polyunsaturated': 5.8,
#    '18:1 t': 0.03,
#    '18:2 CLAs': 0.01,
#    '20:2 n-6 c,c': 0.0,
#    '18:3 n-6 c,c,c': 0.04,
#    'Fiber, total dietary': 3.9,
#    'Iron, Fe': 1.01,
#    'Magnesium, Mg': 29.0,
#    'Phosphorus, P': 137.0,
#    'Sodium, Na': 618.0,
#    'Copper, Cu': 0.11,
#    'Manganese, Mn': 0.27,
#    'Tocopherol, delta': 2.23,
#    'Tocotrienol, gamma': 0.14,
#    'Tocotrienol, delta': 0.03,
#    'Vitamin C, total ascorbic acid': 0.7,
#    'Thiamin': 0.1,
#    'Riboflavin': 0.06,
#    'Dihydrophylloquinone': 0.1,
#    'Vitamin K (phylloquinone)': 33.4,
#    'Protein': 3.31,
#    'Ash': 2.72,
#    'Starch': 35.47,
#    'Fatty acids, total trans': 0.08,
#    'Fatty acids, total saturated': 2.33,
#    '18:1 c': 3.19,
#    '18:2 n-6 c,c': 4.95,
#    '22:1 c': 0.0,
#    '17:1': 0.01,
#    '12:0': 0.0,
#    '14:0': 0.02,
#    '22:0': 0.04,
#    '16:1': 0.02,
#    '20:5 n-3 (EPA)': 0.0,
#    '17:0': 0.01,
#    '24:0': 0.02,
#    'Fatty acids, total trans-monoenoic': 0.03,
#    '18:3 n-3 c,c,c (ALA)': 0.73,
#    '8:0': 0.0,
#    'Cholesterol': 1.0,
#    '22:4': 0.0,
#    'Campesterol': 11.0,
#    'Zinc, Zn': 0.49,
#    'Selenium, Se': 0.4,
#    'Fatty acids, total trans-polyenoic': 0.06,
#    '16:1 c': 0.02,
#    '18:2 t not further defined': 0.06,
#    '15:0': 0.0,
#    'Stigmasterol': 7.0,
#    'Beta-sitosterol': 27.0}],
#  ['ORG BANANAS 2.',
#   'bananas raw',
#   'bananas',
#   {'Fatty acids, total saturated': 0.11,
#    '12:0': 0.0,
#    '14:0': 0.0,
#    '16:1': 0.01,
#    'Energy': 89.0,
#    'Vitamin A, IU': 64.0,
#    'Vitamin A, RAE': 3.0,
#    'Folate, food': 20.0,
#    'Fluoride, F': 2.2,
#    'Choline, total': 9.8,
#    '10:0': 0.0,
#    '16:0': 0.1,
#    '18:0': 0.0,
#    '18:1': 0.02,
#    '18:2': 0.05,
#    '18:3': 0.03,
#    'Fatty acids, total monounsaturated': 0.03,
#    'Fatty acids, total polyunsaturated': 0.07,
#    'Carbohydrate, by difference': 22.84,
#    'Folate, DFE': 20.0,
#    'Betaine': 0.1,
#    'Phytosterols': 16.0,
#    'Vitamin K (phylloquinone)': 0.5,
#    'Tocopherol, delta': 0.01,
#    'Vitamin C, total ascorbic acid': 8.7,
#    'Thiamin': 0.03,
#    'Riboflavin': 0.07,
#    'Folate, total': 20.0,
#    'Tryptophan': 0.01,
#    'Threonine': 0.03,
#    'Methionine': 0.01,
#    'Phenylalanine': 0.05,
#    'Tyrosine': 0.01,
#    'Alanine': 0.04,
#    'Glutamic acid': 0.15,
#    'Glycine': 0.04,
#    'Proline': 0.03,
#    'Carotene, beta': 26.0,
#    'Carotene, alpha': 25.0,
#    'Fiber, total dietary': 2.6,
#    'Iron, Fe': 0.26,
#    'Magnesium, Mg': 27.0,
#    'Phosphorus, P': 22.0,
#    'Sodium, Na': 1.0,
#    'Copper, Cu': 0.08,
#    'Manganese, Mn': 0.27,
#    'Protein': 1.09,
#    'Ash': 0.82,
#    'Starch': 5.38,
#    'Fructose': 4.85,
#    'Sugars, total including NLEA': 12.23,
#    'Calcium, Ca': 5.0,
#    'Potassium, K': 358.0,
#    'Zinc, Zn': 0.15,
#    'Sucrose': 2.39,
#    'Glucose (dextrose)': 4.98,
#    'Maltose': 0.01,
#    'Water': 74.91,
#    'Total lipid (fat)': 0.33,
#    'Isoleucine': 0.03,
#    'Leucine': 0.07,
#    'Lysine': 0.05,
#    'Cystine': 0.01,
#    'Valine': 0.05,
#    'Arginine': 0.05,
#    'Histidine': 0.08,
#    'Aspartic acid': 0.12,
#    'Serine': 0.04,
#    'Lutein + zeaxanthin': 22.0,
#    'Tocopherol, gamma': 0.02,
#    'Tocotrienol, alpha': 0.06,
#    'Niacin': 0.66,
#    'Pantothenic acid': 0.33,
#    'Vitamin B-6': 0.37,
#    'Selenium, Se': 1.0,
#    'Vitamin E (alpha-tocopherol)': 0.1}],
#  ['DELI 2.',
#   'ham sliced prepackaged deli meat ',
#   'ham',
#   {'18:3 n-3 c,c,c (ALA)': 0.01,
#    '20:3 n-3': 0.0,
#    '22:4': 0.01,
#    '18:1 c': 1.35,
#    '18:2 n-6 c,c': 0.44,
#    '17:1': 0.01,
#    'Fatty acids, total trans-monoenoic': 0.01,
#    '12:0': 0.0,
#    '14:0': 0.04,
#    '22:6 n-3 (DHA)': 0.0,
#    '22:0': 0.0,
#    '22:5 n-3 (DPA)': 0.0,
#    '17:0': 0.01,
#    'Fatty acids, total trans': 0.01,
#    'Fatty acids, total saturated': 1.12,
#    'Energy': 106.0,
#    'Iron, Fe': 0.58,
#    'Magnesium, Mg': 18.8,
#    'Phosphorus, P': 261.0,
#    'Sodium, Na': 1040.0,
#    'Copper, Cu': 0.05,
#    'Protein': 16.7,
#    'Ash': 3.61,
#    '10:0': 0.0,
#    '16:0': 0.71,
#    '18:0': 0.35,
#    '20:0': 0.0,
#    '20:4': 0.05,
#    'Total lipid (fat)': 3.73,
#    'Carbohydrate, by difference': 0.27,
#    'Water': 75.7,
#    'Potassium, K': 425.0,
#    'Zinc, Zn': 1.52,
#    'Fatty acids, total monounsaturated': 1.47,
#    'Fatty acids, total polyunsaturated': 0.54,
#    '15:0': 0.0,
#    '18:1 t': 0.01,
#    '18:2 t not further defined': 0.0,
#    '18:2 CLAs': 0.0,
#    '20:2 n-6 c,c': 0.02,
#    '16:1 c': 0.09,
#    '20:3 n-6': 0.01,
#    'Calcium, Ca': 5.0,
#    '20:1 c': 0.03,
#    'Nitrogen': 2.67,
#    'Fatty acids, total trans-dienoic': 0.0,
#    '17:1 c': 0.01,
#    '18:2 c': 0.45,
#    '18:3 c': 0.01,
#    '20:3 c': 0.01,
#    '20:4 c': 0.05,
#    '22:5 c': 0.0,
#    '22:6 c': 0.0,
#    '20:2 c': 0.02,
#    'Total fat (NLEA)': 3.15}],
#  ['PORT SALUT WHEEL 2.',
#   'cheese port de salut',
#   'cheese',
#   {'Sugars, total including NLEA': 0.57,
#    'Vitamin E (alpha-tocopherol)': 0.24,
#    'Vitamin K (phylloquinone)': 2.4,
#    'Carotene, beta': 29.0,
#    'Vitamin A, IU': 1092.0,
#    'Retinol': 313.0,
#    'Vitamin A, RAE': 315.0,
#    'Energy': 352.0,
#    'Folate, food': 18.0,
#    'Vitamin D3 (cholecalciferol)': 0.5,
#    'Vitamin D (D2 + D3)': 0.5,
#    'Vitamin B-6': 0.05,
#    'Choline, total': 15.4,
#    'Vitamin D': 21.0,
#    'Folate, DFE': 18.0,
#    'Niacin': 0.06,
#    'Pantothenic acid': 0.21,
#    'Water': 45.45,
#    'Calcium, Ca': 650.0,
#    'Potassium, K': 136.0,
#    'Zinc, Zn': 2.6,
#    'Total lipid (fat)': 28.2,
#    'Carbohydrate, by difference': 0.57,
#    '4:0': 1.03,
#    '6:0': 0.56,
#    '10:0': 0.68,
#    '16:0': 6.64,
#    '18:0': 3.35,
#    '18:1': 8.05,
#    '18:2': 0.38,
#    '18:3': 0.35,
#    'Fatty acids, total monounsaturated': 9.34,
#    'Fatty acids, total polyunsaturated': 0.73,
#    'Isoleucine': 1.45,
#    'Leucine': 2.48,
#    'Lysine': 1.99,
#    'Cystine': 0.13,
#    'Valine': 1.71,
#    'Arginine': 0.83,
#    'Histidine': 0.69,
#    'Aspartic acid': 1.75,
#    'Serine': 1.36,
#    'Protein': 23.78,
#    'Ash': 2.0,
#    'Iron, Fe': 0.43,
#    'Magnesium, Mg': 24.0,
#    'Phosphorus, P': 360.0,
#    'Sodium, Na': 534.0,
#    'Copper, Cu': 0.02,
#    'Manganese, Mn': 0.01,
#    'Cholesterol': 123.0,
#    'Fatty acids, total saturated': 16.69,
#    '8:0': 0.34,
#    '12:0': 0.77,
#    '14:0': 2.72,
#    'Thiamin': 0.01,
#    'Riboflavin': 0.24,
#    'Folate, total': 18.0,
#    'Vitamin B-12': 1.5,
#    'Tryptophan': 0.34,
#    'Threonine': 0.88,
#    'Methionine': 0.73,
#    'Phenylalanine': 1.32,
#    'Tyrosine': 1.42,
#    'Alanine': 0.79,
#    'Glutamic acid': 5.35,
#    'Glycine': 0.48,
#    'Proline': 2.89,
#    '16:1': 0.83,
#    'Selenium, Se': 14.5}]]

# %%
advanceMatchReceipt(["ORANGE 2.0", "RAW APPLE 3.0"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-58-7f99740e720a> in <module>
# ----> 1 advanceMatchReceipt(["ORANGE 2.0", "RAW APPLE 3.0"])
#
# <ipython-input-54-a64d0aa1e12f> in advanceMatchReceipt(inp)
#      26                 bestRatio = r
#      27         if bestRatio > 60:
# ---> 28             e = difflib.get_close_matches(clean, expr['name'].tolist(), n = 1)[0]
#      29             d = food_categ.loc[pos, 'nutrients']
#      30             nutri = ast.literal_eval(d)
#
# ~/anaconda3/lib/python3.7/difflib.py in get_close_matches(word, possibilities, n, cutoff)
#     724     for x in possibilities:
#     725         s.set_seq1(x)
# --> 726         if s.real_quick_ratio() >= cutoff and \
#     727            s.quick_ratio() >= cutoff and \
#     728            s.ratio() >= cutoff:
#
# ~/anaconda3/lib/python3.7/difflib.py in real_quick_ratio(self)
#     681         """
#     682
# --> 683         la, lb = len(self.a), len(self.b)
#     684         # can't have more matches than the number of elements in the
#     685         # shorter sequence
#
# TypeError: object of type 'float' has no len()

# %%
fuzz.ratio('apple', 'apple juice beverage') <  fuzz.ratio('apple', 'apple')
# Out:
# True

# %%
#         for w in words:
#             r = 0
#             pos = 0
#             name = ""
#             for i, f in enumerate(foodlist_categ):
#                 s = difflib.SequenceMatcher(lambda x: x == ".", w.lower(), f)
#                 if s.ratio() > r:
#                     r = s.ratio()
#                     pos = i
#                     name = f
#             if r > 0.7:
#                 d = food_categ.loc[pos, 'nutrients']
#                 food.append((name, ast.literal_eval(d)))

# %%
expr.shape
# Out:
# (455, 2)

# %%
len(foodList)
# Out:
# 6750

# %%
expr.head()
# Out:
#                                   name  expireIn
# 0                   apple juice canned       540
# 1            apples  applesauce canned       720
# 2                      apricots canned       720
# 3  baby cereal del monte oatmeal based        30
# 4     baby cereal del monte rice based        60
