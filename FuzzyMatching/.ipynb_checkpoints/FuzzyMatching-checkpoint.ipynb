# %%
import difflib
import re
import numpy as np
import pandas as pd
import ast

# %%
# Reads the food with 6,000 rows
with open("../Reference and Datasets/foodList.txt") as f:
    foodList = f.read().splitlines()
    
# Reads the large food data with 200,000 rows
food_nutrient_large = pd.read_csv('../NutrientData/Food Data/food_nutrients_dict.csv')

# Reads categorized food with 16,000 rows
food_categ = pd.read_csv('../NutrientData/food_categorized_nurtrients_w_name.csv')

# %%
# Creates a series of food_names with comma, for regex extracting purposes
food_comma = food_categ['food_name'] + ','

# Extracts the food's generic names 
food_categ['generic'] = food_comma.str.extract(r'^([^,]*),')[0]

# %%
# Compiles a list of foodnames with 200k data and with 16k data respectively
foodlist_large = food_nutrient_large['name'].tolist()
foodlist_categ = food_categ['generic'].tolist()

# %%
food_categ.head()
# Out:
#    Unnamed: 0  fdc_id                           food_name  \
# 0           0  321510           beans snap canned drained
# 1           1  321511  beans, snap, canned, drained - nfy
# 2           2  321519           beans snap canned drained
# 3           3  321520  beans, snap, canned, drained - nfy
# 4           4  321525           beans snap canned drained
#
#                                            nutrients  food_category_id  \
# 0  {'Calcium, Ca': 35.0, 'Copper, Cu': 0.04, 'Iro...              11.0
# 1  {'Ash': 0.94, 'Total lipid (fat)': 0.43, 'Wate...              11.0
# 2  {'Calcium, Ca': 37.0, 'Copper, Cu': 0.04, 'Iro...              11.0
# 3  {'Ash': 1.05, 'Total lipid (fat)': 0.38, 'Wate...              11.0
# 4  {'Calcium, Ca': 34.0, 'Copper, Cu': 0.06, 'Iro...              11.0
#
#                        category_name                                comma  \
# 0  Vegetables and Vegetable Products           beans snap canned drained,
# 1  Vegetables and Vegetable Products  beans, snap, canned, drained - nfy,
# 2  Vegetables and Vegetable Products           beans snap canned drained,
# 3  Vegetables and Vegetable Products  beans, snap, canned, drained - nfy,
# 4  Vegetables and Vegetable Products           beans snap canned drained,
#
#                      generic
# 0  beans snap canned drained
# 1                      beans
# 2  beans snap canned drained
# 3                      beans
# 4  beans snap canned drained

# %%
# RegEx generator to match with decimals surrounded by indices
regexp = re.compile(r'\d\.\d')

# %%
food = []
inp = ['Subtotal : $1.95', 'Cooker. $1.95', 'APpLEea 2.1', 'so pee edi ce sald aan hee paxew Uebel er nla', 'Date: 11/14/18, 9:06 PM',
       'Order# 3913644', 'Se (510) 843-5252', 'wn berkeley, CA 94704', 's; 2300 College Ave.']
for line in inp:
    if regexp.search(line):
        words = line.split(' ')
        for w in words:
            r = 0
            pos = 0
            name = ""
            for i, f in enumerate(foodlist_categ):
                s = difflib.SequenceMatcher(lambda x: x == ".", w.lower(), f)
                if s.ratio() > r:
                    r = s.ratio()
                    pos = i
                    name = f
            if r > 0.7:
                d = food_categ.loc[pos, 'nutrients']
                food.append((name, ast.literal_eval(d)))

# %%
food[0][1]
# Out:
# {'Total lipid (fat)': 25.8,
#  'Carbohydrate, by difference': 64.1,
#  'Energy': 2046.0,
#  'Water': 5.7,
#  'Caffeine': 18.0,
#  'Theobromine': 157.0,
#  'Sugars, total including NLEA': 35.8,
#  'Calcium, Ca': 40.0,
#  'Potassium, K': 195.0,
#  'Zinc, Zn': 0.5,
#  'Selenium, Se': 9.4,
#  'Vitamin E (alpha-tocopherol)': 2.42,
#  'Vitamin D': 1.0,
#  'Lutein + zeaxanthin': 10.0,
#  'Niacin': 1.2,
#  'Pantothenic acid': 0.14,
#  'Vitamin B-6': 0.05,
#  'Choline, total': 11.4,
#  'Folic acid': 20.0,
#  'Folate, DFE': 42.0,
#  'Isoleucine': 0.1,
#  'Leucine': 0.19,
#  'Lysine': 0.1,
#  'Cystine': 0.04,
#  'Valine': 0.12,
#  'Arginine': 0.15,
#  'Histidine': 0.06,
#  'Aspartic acid': 0.15,
#  'Serine': 0.13,
#  '4:0': 0.04,
#  '6:0': 0.07,
#  '10:0': 0.44,
#  '16:0': 6.24,
#  '18:0': 5.36,
#  '20:0': 0.13,
#  '18:1': 2.79,
#  '18:2': 3.45,
#  '18:3': 0.08,
#  '20:1': 0.0,
#  'Fatty acids, total monounsaturated': 2.8,
#  'Fatty acids, total polyunsaturated': 3.7,
#  '15:0': 0.01,
#  'Protein': 3.5,
#  'Ash': 0.77,
#  'Fiber, total dietary': 4.4,
#  'Iron, Fe': 3.2,
#  'Magnesium, Mg': 30.0,
#  'Phosphorus, P': 76.0,
#  'Sodium, Na': 182.0,
#  'Copper, Cu': 0.38,
#  'Manganese, Mn': 0.23,
#  'Vitamin A, IU': 25.0,
#  'Retinol': 6.0,
#  'Vitamin A, RAE': 6.0,
#  'Carotene, beta': 1.0,
#  'Vitamin C, total ascorbic acid': 0.2,
#  'Thiamin': 0.14,
#  'Riboflavin': 0.12,
#  'Folate, total': 28.0,
#  'Vitamin B-12': 0.04,
#  'Vitamin K (phylloquinone)': 5.0,
#  'Folate, food': 8.0,
#  'Tryptophan': 0.03,
#  'Threonine': 0.08,
#  'Methionine': 0.05,
#  'Phenylalanine': 0.12,
#  'Tyrosine': 0.08,
#  'Alanine': 0.09,
#  'Glutamic acid': 0.7,
#  'Glycine': 0.08,
#  'Proline': 0.24,
#  'Cholesterol': 2.0,
#  'Fatty acids, total trans': 0.2,
#  'Fatty acids, total saturated': 17.7,
#  '8:0': 0.56,
#  '12:0': 3.23,
#  '14:0': 1.37,
#  '22:0': 0.13,
#  '16:1': 0.01,
#  '17:0': 0.05,
#  '24:0': 0.0}

# %%
food
# Out:
# [('cookie',
#   {'Total lipid (fat)': 25.8,
#    'Carbohydrate, by difference': 64.1,
#    'Energy': 2046.0,
#    'Water': 5.7,
#    'Caffeine': 18.0,
#    'Theobromine': 157.0,
#    'Sugars, total including NLEA': 35.8,
#    'Calcium, Ca': 40.0,
#    'Potassium, K': 195.0,
#    'Zinc, Zn': 0.5,
#    'Selenium, Se': 9.4,
#    'Vitamin E (alpha-tocopherol)': 2.42,
#    'Vitamin D': 1.0,
#    'Lutein + zeaxanthin': 10.0,
#    'Niacin': 1.2,
#    'Pantothenic acid': 0.14,
#    'Vitamin B-6': 0.05,
#    'Choline, total': 11.4,
#    'Folic acid': 20.0,
#    'Folate, DFE': 42.0,
#    'Isoleucine': 0.1,
#    'Leucine': 0.19,
#    'Lysine': 0.1,
#    'Cystine': 0.04,
#    'Valine': 0.12,
#    'Arginine': 0.15,
#    'Histidine': 0.06,
#    'Aspartic acid': 0.15,
#    'Serine': 0.13,
#    '4:0': 0.04,
#    '6:0': 0.07,
#    '10:0': 0.44,
#    '16:0': 6.24,
#    '18:0': 5.36,
#    '20:0': 0.13,
#    '18:1': 2.79,
#    '18:2': 3.45,
#    '18:3': 0.08,
#    '20:1': 0.0,
#    'Fatty acids, total monounsaturated': 2.8,
#    'Fatty acids, total polyunsaturated': 3.7,
#    '15:0': 0.01,
#    'Protein': 3.5,
#    'Ash': 0.77,
#    'Fiber, total dietary': 4.4,
#    'Iron, Fe': 3.2,
#    'Magnesium, Mg': 30.0,
#    'Phosphorus, P': 76.0,
#    'Sodium, Na': 182.0,
#    'Copper, Cu': 0.38,
#    'Manganese, Mn': 0.23,
#    'Vitamin A, IU': 25.0,
#    'Retinol': 6.0,
#    'Vitamin A, RAE': 6.0,
#    'Carotene, beta': 1.0,
#    'Vitamin C, total ascorbic acid': 0.2,
#    'Thiamin': 0.14,
#    'Riboflavin': 0.12,
#    'Folate, total': 28.0,
#    'Vitamin B-12': 0.04,
#    'Vitamin K (phylloquinone)': 5.0,
#    'Folate, food': 8.0,
#    'Tryptophan': 0.03,
#    'Threonine': 0.08,
#    'Methionine': 0.05,
#    'Phenylalanine': 0.12,
#    'Tyrosine': 0.08,
#    'Alanine': 0.09,
#    'Glutamic acid': 0.7,
#    'Glycine': 0.08,
#    'Proline': 0.24,
#    'Cholesterol': 2.0,
#    'Fatty acids, total trans': 0.2,
#    'Fatty acids, total saturated': 17.7,
#    '8:0': 0.56,
#    '12:0': 3.23,
#    '14:0': 1.37,
#    '22:0': 0.13,
#    '16:1': 0.01,
#    '17:0': 0.05,
#    '24:0': 0.0}),
#  ('apples',
#   {'Folate, DFE': 3.0,
#    'Folate, total': 3.0,
#    'Choline, total': 3.4,
#    'Fluoride, F': 3.3,
#    'Betaine': 0.1,
#    'Carbohydrate, by difference': 13.81,
#    'Energy': 218.0,
#    '16:0': 0.02,
#    '18:0': 0.0,
#    '18:1': 0.01,
#    '18:2': 0.04,
#    '18:3': 0.01,
#    'Fatty acids, total monounsaturated': 0.01,
#    'Fatty acids, total polyunsaturated': 0.05,
#    'Fatty acids, total saturated': 0.03,
#    '14:0': 0.0,
#    'Folate, food': 3.0,
#    'Vitamin E (alpha-tocopherol)': 0.18,
#    'Total lipid (fat)': 0.17,
#    'Lutein + zeaxanthin': 29.0,
#    'Niacin': 0.09,
#    'Pantothenic acid': 0.06,
#    'Vitamin B-6': 0.04,
#    'Sucrose': 2.07,
#    'Glucose (dextrose)': 2.43,
#    'Sugars, total including NLEA': 10.39,
#    'Calcium, Ca': 6.0,
#    'Potassium, K': 107.0,
#    'Zinc, Zn': 0.04,
#    'Water': 85.56,
#    'Vitamin K (phylloquinone)': 2.2,
#    'Vitamin A, RAE': 3.0,
#    'Carotene, beta': 27.0,
#    'Cryptoxanthin, beta': 11.0,
#    'Fiber, total dietary': 2.4,
#    'Iron, Fe': 0.12,
#    'Magnesium, Mg': 5.0,
#    'Phosphorus, P': 11.0,
#    'Sodium, Na': 1.0,
#    'Copper, Cu': 0.03,
#    'Manganese, Mn': 0.04,
#    'Vitamin A, IU': 54.0,
#    'Thiamin': 0.02,
#    'Riboflavin': 0.03,
#    'Fructose': 5.9,
#    'Protein': 0.26,
#    'Ash': 0.19,
#    'Phytosterols': 12.0,
#    'Isoleucine': 0.01,
#    'Leucine': 0.01,
#    'Lysine': 0.01,
#    'Cystine': 0.0,
#    'Valine': 0.01,
#    'Arginine': 0.01,
#    'Histidine': 0.0,
#    'Aspartic acid': 0.07,
#    'Serine': 0.01,
#    'Tryptophan': 0.0,
#    'Threonine': 0.01,
#    'Methionine': 0.0,
#    'Phenylalanine': 0.01,
#    'Tyrosine': 0.0,
#    'Alanine': 0.01,
#    'Glutamic acid': 0.02,
#    'Glycine': 0.01,
#    'Proline': 0.01,
#    'Vitamin C, total ascorbic acid': 4.6,
#    'Starch': 0.05})]
